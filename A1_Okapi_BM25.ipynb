# %% [markdown]
# # Demostration of Okapi BM25 Model

# %%
pip install rank_bm25

# %%
from rank_bm25 import BM25Okapi

corpus = [
    "Hello there good man!",
    "It is quite windy in London",
    "How is the weather today?"
]

tokenized_corpus = [doc.split(" ") for doc in corpus]

bm25 = BM25Okapi(tokenized_corpus)
# <rank_bm25.BM25Okapi at 0x1047881d0>

# %%
query = "windy London"
tokenized_query = query.split(" ")

doc_scores = bm25.get_scores(tokenized_query)
# array([0.        , 0.93729472, 0.        ])

# %%
bm25.get_top_n(tokenized_query, corpus, n=1)
# ['It is quite windy in London']
# Out:
# ['It is quite windy in London']

# %% [markdown]
# ## Make different examples on other Corpus.

# %% [markdown]
# ### Best Video Game Quotes

# %%
from rank_bm25 import BM25Okapi

corpus = [
    "The right man in the wrong place can make all the difference in the world", # G-Man, Half Life 2
    "Don't wish it were easier, wish you were better", # Chief, Animal Crossing
    "Nothing is true, everything is permitted",  # Ezio Auditore, Assassin's Creed 2
    "War. War never changes", # Fallout 3
    "Endure and survive", # Ellie, The Last of Us
    "Stay awhile, and listen",  # Deckard Cain, Diablo 2
    "Thank you Mario! But our princess is in another castle", # Toad, Super Mario Bros
    "Every puzzle has an answer", #  Professor Layton
    "They say that a man never really knows himself until his freedom has been taken away", # Starcraft II: Wings of Liberty
    "You forget a thousand things every day make sure this is one of them" # Michael Townley, GTA V
]

tokenized_corpus = [doc.split(" ") for doc in corpus]

bm25 = BM25Okapi(tokenized_corpus)
# <rank_bm25.BM25Okapi at 0x1047881d0>

# %%
query = "puzzle answer"
tokenized_query = query.split(" ")

doc_scores = bm25.get_scores(tokenized_query)
print(doc_scores)
# array([0.        , 0.93729472, 0.        ])
# Out:
# [0.         0.         0.         0.         0.         0.
#  0.         4.54845546 0.         0.        ]

# %% [markdown]
# Query : "puzzle answer"
#
# [7] : 'Every **puzzle** has an **answer**'

# %%
bm25.get_top_n(tokenized_query, corpus, n=1)
# ['Every puzzle has an answer']
# Out:
# ['Every puzzle has an answer']

# %%
query = "make sure"
tokenized_query = query.split(" ")

doc_scores = bm25.get_scores(tokenized_query)
doc_scores
# [0.91676557 0.         0.         0.         0.         0.
#  0.         0.         0.         2.39334345]
# Out:
# array([0.91676557, 0.        , 0.        , 0.        , 0.        ,
#        0.        , 0.        , 0.        , 0.        , 2.39334345])

# %% [markdown]
# Query : "make sure"
#
# [0] : 'The right man in the wrong place can **make** all the difference in the world'
#
# [9] : 'You forget a thousand things every day **make sure** this is one of them'

# %%
bm25.get_top_n(tokenized_query, corpus, n=1)
# ['You forget a thousand things every day make sure this is one of them']
# Out:
# ['You forget a thousand things every day make sure this is one of them']

# %% [markdown]
# # Okapi BM25 on Korean Documents
#
# Korean words are not completely separated by " ", so we need a new solution.

# %%
from rank_bm25 import BM25Okapi

corpus = [
    "세계 배달 피자 리더 도미노피자가 우리 고구마를 활용한 신메뉴를 출시한다.도미노피자는 오는 2월 1일 국내산 고구마와 4가지 치즈가 어우러진 신메뉴 `우리 고구마 피자`를 출시하고 전 매장에서 판매를 시작한다. 이번에 도미노피자가 내놓은 신메뉴 `우리 고구마 피자`는 까다롭게 엄선한 국내산 고구마를 무스와 큐브 형태로 듬뿍 올리고, 모차렐라, 카망베르, 체더 치즈와 리코타 치즈 소스 등 4가지 치즈와 와규 크럼블을 더한 프리미엄 고구마 피자다.",
    "피자의 발상지이자 원조라고 할 수 있는 남부의 나폴리식 피자(Pizza Napolitana)는 재료 본연의 맛에 집중하여 뛰어난 식감을 자랑한다. 대표적인 나폴리 피자로는 피자 마리나라(Pizza Marinara)와 피자 마르게리타(Pizza Margherita)가 있다.",
    "도미노피자가 삼일절을 맞아 '방문포장 1+1' 이벤트를 진행한다. 이번 이벤트는 도미노피자 102개 매장에서 3월 1일 단 하루 동안 방문포장 온라인, 오프라인 주문 시 피자 1판을 더 증정하는 이벤트다. 온라인 주문 시 장바구니에 2판을 담은 후 할인 적용이 가능하며, 동일 가격 또는 낮은 가격의 피자를 고객이 선택하면 무료로 증정한다."
]

def tokenizer(sent):
  return sent.split(" ")

tokenized_corpus = [tokenizer(doc) for doc in corpus]

bm25 = BM25Okapi(tokenized_corpus)

# %%
bm25.doc_len
# Out:
# [59, 27, 47]

# %%
bm25.doc_freqs
# Out:
# [{'세계': 1,
#   '배달': 1,
#   '피자': 1,
#   '리더': 1,
#   '도미노피자가': 2,
#   '우리': 1,
#   '고구마를': 2,
#   '활용한': 1,
#   '신메뉴를': 1,
#   '출시한다.도미노피자는': 1,
#   '오는': 1,
#   '2월': 1,
#   '1일': 1,
#   '국내산': 2,
#   '고구마와': 1,
#   '4가지': 2,
#   '치즈가': 1,
#   '어우러진': 1,
#   '신메뉴': 2,
#   '`우리': 2,
#   '고구마': 3,
#   '피자`를': 1,
#   '출시하고': 1,
#   '전': 1,
#   '매장에서': 1,
#   '판매를': 1,
#   '시작한다.': 1,
#   '이번에': 1,
#   '내놓은': 1,
#   '피자`는': 1,
#   '까다롭게': 1,
#   '엄선한': 1,
#   '무스와': 1,
#   '큐브': 1,
#   '형태로': 1,
#   '듬뿍': 1,
#   '올리고,': 1,
#   '모차렐라,': 1,
#   '카망베르,': 1,
#   '체더': 1,
#   '치즈와': 2,
#   '리코타': 1,
#   '치즈': 1,
#   '소스': 1,
#   '등': 1,
#   '와규': 1,
#   '크럼블을': 1,
#   '더한': 1,
#   '프리미엄': 1,
#   '피자다.': 1},
#  {'피자의': 1,
#   '발상지이자': 1,
#   '원조라고': 1,
#   '할': 1,
#   '수': 1,
#   '있는': 1,
#   '남부의': 1,
#   '나폴리식': 1,
#   '피자(Pizza': 1,
#   'Napolitana)는': 1,
#   '재료': 1,
#   '본연의': 1,
#   '맛에': 1,
#   '집중하여': 1,
#   '뛰어난': 1,
#   '식감을': 1,
#   '자랑한다.': 1,
#   '대표적인': 1,
#   '나폴리': 1,
# ...

# %%
bm25.idf
# Out:
# {'세계': 0.5108256237659907,
#  '배달': 0.5108256237659907,
#  '피자': 0.11580621302033972,
#  '리더': 0.5108256237659907,
#  '도미노피자가': 0.11580621302033972,
#  '우리': 0.5108256237659907,
#  '고구마를': 0.5108256237659907,
#  '활용한': 0.5108256237659907,
#  '신메뉴를': 0.5108256237659907,
#  '출시한다.도미노피자는': 0.5108256237659907,
#  '오는': 0.5108256237659907,
#  '2월': 0.5108256237659907,
#  '1일': 0.11580621302033972,
#  '국내산': 0.5108256237659907,
#  '고구마와': 0.5108256237659907,
#  '4가지': 0.5108256237659907,
#  '치즈가': 0.5108256237659907,
#  '어우러진': 0.5108256237659907,
#  '신메뉴': 0.5108256237659907,
#  '`우리': 0.5108256237659907,
#  '고구마': 0.5108256237659907,
#  '피자`를': 0.5108256237659907,
#  '출시하고': 0.5108256237659907,
#  '전': 0.5108256237659907,
#  '매장에서': 0.11580621302033972,
#  '판매를': 0.5108256237659907,
#  '시작한다.': 0.5108256237659907,
#  '이번에': 0.5108256237659907,
#  '내놓은': 0.5108256237659907,
#  '피자`는': 0.5108256237659907,
#  '까다롭게': 0.5108256237659907,
#  '엄선한': 0.5108256237659907,
# ...

# %% [markdown]
# ## Using Tokenizer 'split()' Function

# %%
query = "도미노피자 신메뉴"
tokenized_query = tokenizer(query)

doc_scores = bm25.get_scores(tokenized_query)
doc_scores
# Out:
# array([0.65960979, 0.        , 0.49736316])

# %%
bm25.get_top_n(tokenized_query, corpus, n=1)
# Out:
# ['세계 배달 피자 리더 도미노피자가 우리 고구마를 활용한 신메뉴를 출시한다.도미노피자는 오는 2월 1일 국내산 고구마와 4가지 치즈가 어우러진 신메뉴 `우리 고구마 피자`를 출시하고 전 매장에서 판매를 시작한다. 이번에 도미노피자가 내놓은 신메뉴 `우리 고구마 피자`는 까다롭게 엄선한 국내산 고구마를 무스와 큐브 형태로 듬뿍 올리고, 모차렐라, 카망베르, 체더 치즈와 리코타 치즈 소스 등 4가지 치즈와 와규 크럼블을 더한 프리미엄 고구마 피자다.']

# %% [markdown]
# ## Using 'bigram()' function for Okapi BM25

# %%
def bigram(str):
  result = []
  for word in str.split():
    prev = ''
    for c in word:
      if prev:
        result.append(prev + c)
      prev = c
  return result

# %%
bigram('한국어 테스트')
# Out:
# ['한국', '국어', '테스', '스트']

# %% [markdown]
# ### Bigram for Corpus

# %%
bigramed_corpus = [bigram(doc) for doc in corpus]

bm25 = BM25Okapi(bigramed_corpus)

# %%
bm25.doc_len
# Out:
# [133, 99, 97]

# %%
bm25.doc_freqs
# Out:
# [{'세계': 1,
#   '배달': 1,
#   '피자': 7,
#   '리더': 1,
#   '도미': 3,
#   '미노': 3,
#   '노피': 3,
#   '자가': 2,
#   '우리': 3,
#   '고구': 6,
#   '구마': 6,
#   '마를': 2,
#   '활용': 1,
#   '용한': 1,
#   '신메': 3,
#   '메뉴': 3,
#   '뉴를': 1,
#   '출시': 2,
#   '시한': 1,
#   '한다': 2,
#   '다.': 3,
#   '.도': 1,
#   '자는': 1,
#   '오는': 1,
#   '2월': 1,
#   '1일': 1,
#   '국내': 2,
#   '내산': 2,
#   '마와': 1,
#   '4가': 2,
#   '가지': 2,
#   '치즈': 4,
#   '즈가': 1,
#   '어우': 1,
#   '우러': 1,
#   '러진': 1,
#   '`우': 2,
#   '자`': 2,
#   '`를': 1,
#   '시하': 1,
#   '하고': 1,
#   '매장': 1,
#   '장에': 1,
#   '에서': 1,
#   '판매': 1,
#   '매를': 1,
#   '시작': 1,
#   '작한': 1,
#   '이번': 1,
#   '번에': 1,
#   '내놓': 1,
#   '놓은': 1,
#   '`는': 1,
#   '까다': 1,
#   '다롭': 1,
#   '롭게': 1,
#   '엄선': 1,
#   '선한': 1,
#   '무스': 1,
#   '스와': 1,
#   '큐브': 1,
#   '형태': 1,
#   '태로': 1,
#   '듬뿍': 1,
#   '올리': 1,
#   '리고': 1,
#   '고,': 1,
#   '모차': 1,
#   '차렐': 1,
#   '렐라': 1,
#   '라,': 1,
#   '카망': 1,
#   '망베': 1,
#   '베르': 1,
#   '르,': 1,
#   '체더': 1,
# ...

# %%
bm25.idf
# Out:
# {'세계': 0.5108256237659907,
#  '배달': 0.5108256237659907,
#  '피자': 0.10896764061768376,
#  '리더': 0.5108256237659907,
#  '도미': 0.10896764061768376,
#  '미노': 0.10896764061768376,
#  '노피': 0.10896764061768376,
#  '자가': 0.10896764061768376,
#  '우리': 0.5108256237659907,
#  '고구': 0.5108256237659907,
#  '구마': 0.5108256237659907,
#  '마를': 0.5108256237659907,
#  '활용': 0.5108256237659907,
#  '용한': 0.5108256237659907,
#  '신메': 0.5108256237659907,
#  '메뉴': 0.5108256237659907,
#  '뉴를': 0.5108256237659907,
#  '출시': 0.5108256237659907,
#  '시한': 0.5108256237659907,
#  '한다': 0.10896764061768376,
#  '다.': 0.10896764061768376,
#  '.도': 0.5108256237659907,
#  '자는': 0.5108256237659907,
#  '오는': 0.5108256237659907,
#  '2월': 0.5108256237659907,
#  '1일': 0.10896764061768376,
#  '국내': 0.5108256237659907,
#  '내산': 0.5108256237659907,
#  '마와': 0.5108256237659907,
#  '4가': 0.5108256237659907,
#  '가지': 0.5108256237659907,
#  '치즈': 0.5108256237659907,
#  '즈가': 0.5108256237659907,
#  '어우': 0.5108256237659907,
# ...

# %% [markdown]
# ### Bigram for Query

# %%
query = "도미노피자 신메뉴"
tokenized_query = bigram(query)
tokenized_query
# Out:
# ['도미', '미노', '노피', '피자', '신메', '메뉴']

# %%
doc_scores = bm25.get_scores(tokenized_query)
doc_scores
# Out:
# array([2.35227619, 0.21314122, 0.68792738])

# %%
bm25.get_top_n(tokenized_query, corpus, n=1)
# Out:
# ['세계 배달 피자 리더 도미노피자가 우리 고구마를 활용한 신메뉴를 출시한다.도미노피자는 오는 2월 1일 국내산 고구마와 4가지 치즈가 어우러진 신메뉴 `우리 고구마 피자`를 출시하고 전 매장에서 판매를 시작한다. 이번에 도미노피자가 내놓은 신메뉴 `우리 고구마 피자`는 까다롭게 엄선한 국내산 고구마를 무스와 큐브 형태로 듬뿍 올리고, 모차렐라, 카망베르, 체더 치즈와 리코타 치즈 소스 등 4가지 치즈와 와규 크럼블을 더한 프리미엄 고구마 피자다.']

# %% [markdown]
# ## Make different examples on other Corpus.
#
# New Examples : Korean Ballad Lyrics with only Korean

# %%
from rank_bm25 import BM25Okapi

corpus = [
    "일부러 몇 발자국 물러나 내가 없이 혼자 걷는 널 바라본다 옆자리 허전한 너의 풍경 흑백 거리 가운데 넌 뒤돌아본다 그때 알게 되었어 난 널 떠날 수 없단 걸 우리 사이에 그 어떤 힘든 일도 이별보단 버틸 수 있는 것들이었죠 한 발 한 발 이별에 가까워질수록 너와 맞잡은 손이 사라지는 것 같죠 어떻게 이별까지 사랑하겠어 널 사랑하는 거지 사랑이라는 이유로 서로를 포기하고 찢어질 것같이 아파할 수 없어 난 어떻게 내가 어떻게 너를 이후에 우리 바다처럼 깊은 사랑이 다 마를 때까지 기다리는 게 이별일 텐데", # 어떻게 이별까지 사랑하겠어 널 사랑하는 거지 - AKMU
    "두세 번 더 길을 돌아갈까 적막 짙은 도로 위에 걸음을 포갠다 아무 말 없는 대화 나누며 주마등이 길을 비춘 먼 곳을 본다 그때 알게 되었어 난 더 갈 수 없단 걸 널 품기 전 알지 못했다 내 머문 세상 이토록 찬란한 것을 작은 숨결로 닿은 사람 겁 없이 나를 불러준 사랑 몹시도 좋았다 너를 지켜보고 설레고 우습게 질투도 했던 평범한 모든 순간들이 캄캄한 영원 그 오랜 기다림 속으로 햇살처럼 니가 내렸다 널 놓기 전 알지 못했다 내 머문 세상 이토록 쓸쓸한 것을 고운 꽃이 피고 진 이곳 다시는 없을 너라는 계절 욕심이 생겼다 너와 함께 살고 늙어가 주름진 손을 맞잡고 내 삶은 따뜻했었다고 단 한 번 축복 그 짧은 마주침이 지나 빗물처럼 너는 울었다 한 번쯤은 행복하고 싶었던 바람 너까지 울게 만들었을까 모두 잊고 살아가라 내가 널 찾을 테니 니 숨결 다시 나를 부를 때 잊지 않겠다 너를 지켜보고 설레고 우습게 질투도 했던 니가 준 모든 순간들을 언젠가 만날 우리 가장 행복할 그날 첫눈처럼 내가 가겠다 너에게 내가 가겠다", # 첫눈처럼 너에게 가겠다 - 에일리
    "처음이란 건 돌아보면 네가 흘렸던 작은 말들 무심한 듯 담았어 나도 모르게 하늘을 봐도 알 수 없어 네가 말하던 그 계절이 오면 혹시라도 그대가 여기 흰 눈 속에서 보이는 시린 기억이 스쳐요 그댈 본다면 나을까요 걷다 보면 이따금 속삭여 했던 말들 기억하고 있어요 흰 거리에서 보이는 겨울바람이 스쳐요 그댈 본다면 나 울까요 날 붙잡던 손 날 보던 그 두 눈이 언젠가 날 꼭 안아주세요 참을 수 있죠 조금 망설이면 어느새 그댄 내 곁으로 다가와 아무 생각 않을래요 끝이라고 생각했죠 처음 모습대로 날 기억하나요 겨울인데도 봄바람이 부네요 하얀 눈이 걷히면 이곳에 그대가 있겠죠 따스한 햇살이 부는 날 너에게로 다시 돌아가 너와 함께한 기억처럼만" # 겨울봄 - 이세계아이돌
]

# %% [markdown]
# ### 1. By Tokenizer

# %%
tokenized_corpus = [tokenizer(doc) for doc in corpus]

bm25 = BM25Okapi(tokenized_corpus)

# %%
bm25.doc_len
# Out:
# [83, 159, 102]

# %%
bm25.doc_freqs
# Out:
# [{'일부러': 1,
#   '몇': 1,
#   '발자국': 1,
#   '물러나': 1,
#   '내가': 2,
#   '없이': 1,
#   '혼자': 1,
#   '걷는': 1,
#   '널': 3,
#   '바라본다': 1,
#   '옆자리': 1,
#   '허전한': 1,
#   '너의': 1,
#   '풍경': 1,
#   '흑백': 1,
#   '거리': 1,
#   '가운데': 1,
#   '넌': 1,
#   '뒤돌아본다': 1,
#   '그때': 1,
#   '알게': 1,
#   '되었어': 1,
#   '난': 2,
#   '떠날': 1,
#   '수': 3,
#   '없단': 1,
#   '걸': 1,
#   '우리': 2,
#   '사이에': 1,
#   '그': 1,
#   '어떤': 1,
#   '힘든': 1,
#   '일도': 1,
#   '이별보단': 1,
#   '버틸': 1,
#   '있는': 1,
#   '것들이었죠': 1,
#   '한': 2,
#   '발': 2,
#   '이별에': 1,
#   '가까워질수록': 1,
#   '너와': 1,
#   '맞잡은': 1,
#   '손이': 1,
#   '사라지는': 1,
#   '것': 1,
#   '같죠': 1,
#   '어떻게': 3,
#   '이별까지': 1,
#   '사랑하겠어': 1,
#   '사랑하는': 1,
#   '거지': 1,
#   '사랑이라는': 1,
#   '이유로': 1,
#   '서로를': 1,
#   '포기하고': 1,
#   '찢어질': 1,
#   '것같이': 1,
#   '아파할': 1,
#   '없어': 1,
#   '너를': 1,
#   '이후에': 1,
#   '바다처럼': 1,
#   '깊은': 1,
#   '사랑이': 1,
#   '다': 1,
#   '마를': 1,
#   '때까지': 1,
#   '기다리는': 1,
#   '게': 1,
#   '이별일': 1,
#   '텐데': 1},
#  {'두세': 1,
# ...

# %%
bm25.idf
# Out:
# {'일부러': 0.5108256237659907,
#  '몇': 0.5108256237659907,
#  '발자국': 0.5108256237659907,
#  '물러나': 0.5108256237659907,
#  '내가': 0.1024407634683173,
#  '없이': 0.1024407634683173,
#  '혼자': 0.5108256237659907,
#  '걷는': 0.5108256237659907,
#  '널': 0.1024407634683173,
#  '바라본다': 0.5108256237659907,
#  '옆자리': 0.5108256237659907,
#  '허전한': 0.5108256237659907,
#  '너의': 0.5108256237659907,
#  '풍경': 0.5108256237659907,
#  '흑백': 0.5108256237659907,
#  '거리': 0.5108256237659907,
#  '가운데': 0.5108256237659907,
#  '넌': 0.5108256237659907,
#  '뒤돌아본다': 0.5108256237659907,
#  '그때': 0.1024407634683173,
#  '알게': 0.1024407634683173,
#  '되었어': 0.1024407634683173,
#  '난': 0.1024407634683173,
#  '떠날': 0.5108256237659907,
#  '수': 0.1024407634683173,
#  '없단': 0.1024407634683173,
#  '걸': 0.1024407634683173,
#  '우리': 0.1024407634683173,
#  '사이에': 0.5108256237659907,
#  '그': 0.1024407634683173,
#  '어떤': 0.5108256237659907,
#  '힘든': 0.5108256237659907,
#  '일도': 0.5108256237659907,
#  '이별보단': 0.5108256237659907,
# ...

# %% [markdown]
# [0] : 어떻게 **이별**까지 사랑하겠어... (중략)... 이후에 우리 **바다**처럼 깊은 사랑이 다 마를 때까지 기다리는 게 **이별**일 텐데
#
# '바다'와 '이별'이 들어간 문서가 있음에도 검색되지 않는다.

# %%
query = "바다 이별"
tokenized_query = tokenizer(query)

doc_scores = bm25.get_scores(tokenized_query)
doc_scores
# Out:
# array([0., 0., 0.])

# %% [markdown]
# [2] : (전략)... **겨울**인데도 **봄바람**이 부네요 ...(후략)
#
# '겨울'과 '봄바람'이 들어간 문서가 있음에도 검색되지 않는다.

# %%
query = "겨울 봄바람"
tokenized_query = tokenizer(query)

doc_scores = bm25.get_scores(tokenized_query)
doc_scores
# Out:
# array([0., 0., 0.])

# %% [markdown]
# ### 2. By Bigram

# %%
bigramed_corpus = [bigram(doc) for doc in corpus]

bm25 = BM25Okapi(bigramed_corpus)

# %%
bm25.doc_len
# Out:
# [118, 204, 157]

# %%
bm25.doc_freqs
# Out:
# [{'일부': 1,
#   '부러': 1,
#   '발자': 1,
#   '자국': 1,
#   '물러': 1,
#   '러나': 1,
#   '내가': 2,
#   '없이': 1,
#   '혼자': 1,
#   '걷는': 1,
#   '바라': 1,
#   '라본': 1,
#   '본다': 2,
#   '옆자': 1,
#   '자리': 1,
#   '허전': 1,
#   '전한': 1,
#   '너의': 1,
#   '풍경': 1,
#   '흑백': 1,
#   '거리': 1,
#   '가운': 1,
#   '운데': 1,
#   '뒤돌': 1,
#   '돌아': 1,
#   '아본': 1,
#   '그때': 1,
#   '알게': 1,
#   '되었': 1,
#   '었어': 1,
#   '떠날': 1,
#   '없단': 1,
#   '우리': 2,
#   '사이': 1,
#   '이에': 1,
#   '어떤': 1,
#   '힘든': 1,
#   '일도': 1,
#   '이별': 4,
#   '별보': 1,
#   '보단': 1,
#   '버틸': 1,
#   '있는': 1,
#   '것들': 1,
#   '들이': 1,
#   '이었': 1,
#   '었죠': 1,
#   '별에': 1,
#   '가까': 1,
#   '까워': 1,
#   '워질': 1,
#   '질수': 1,
#   '수록': 1,
#   '너와': 1,
#   '맞잡': 1,
#   '잡은': 1,
#   '손이': 1,
#   '사라': 1,
#   '라지': 1,
#   '지는': 1,
#   '같죠': 1,
#   '어떻': 3,
#   '떻게': 3,
#   '별까': 1,
#   '까지': 2,
#   '사랑': 4,
#   '랑하': 2,
#   '하겠': 1,
#   '겠어': 1,
#   '하는': 1,
#   '거지': 1,
#   '랑이': 2,
#   '이라': 1,
#   '라는': 1,
#   '이유': 1,
#   '유로': 1,
# ...

# %%
bm25.idf
# Out:
# {'일부': 0.5108256237659907,
#  '부러': 0.5108256237659907,
#  '발자': 0.5108256237659907,
#  '자국': 0.5108256237659907,
#  '물러': 0.5108256237659907,
#  '러나': 0.5108256237659907,
#  '내가': 0.0948713352151056,
#  '없이': 0.0948713352151056,
#  '혼자': 0.5108256237659907,
#  '걷는': 0.5108256237659907,
#  '바라': 0.5108256237659907,
#  '라본': 0.5108256237659907,
#  '본다': 0.0948713352151056,
#  '옆자': 0.5108256237659907,
#  '자리': 0.5108256237659907,
#  '허전': 0.5108256237659907,
#  '전한': 0.5108256237659907,
#  '너의': 0.5108256237659907,
#  '풍경': 0.5108256237659907,
#  '흑백': 0.5108256237659907,
#  '거리': 0.0948713352151056,
#  '가운': 0.5108256237659907,
#  '운데': 0.5108256237659907,
#  '뒤돌': 0.5108256237659907,
#  '돌아': 0.0948713352151056,
#  '아본': 0.5108256237659907,
#  '그때': 0.0948713352151056,
#  '알게': 0.0948713352151056,
#  '되었': 0.0948713352151056,
#  '었어': 0.0948713352151056,
#  '떠날': 0.5108256237659907,
#  '없단': 0.0948713352151056,
#  '우리': 0.0948713352151056,
#  '사이': 0.5108256237659907,
# ...

# %%
query = "바다 이별"
tokenized_query = bigram(query)
tokenized_query
# Out:
# ['바다', '이별']

# %%
doc_scores = bm25.get_scores(tokenized_query)
doc_scores
# Out:
# array([1.55994044, 0.        , 0.        ])

# %%
bm25.get_top_n(tokenized_query, corpus, n=1)
# Out:
# ['일부러 몇 발자국 물러나 내가 없이 혼자 걷는 널 바라본다 옆자리 허전한 너의 풍경 흑백 거리 가운데 넌 뒤돌아본다 그때 알게 되었어 난 널 떠날 수 없단 걸 우리 사이에 그 어떤 힘든 일도 이별보단 버틸 수 있는 것들이었죠 한 발 한 발 이별에 가까워질수록 너와 맞잡은 손이 사라지는 것 같죠 어떻게 이별까지 사랑하겠어 널 사랑하는 거지 사랑이라는 이유로 서로를 포기하고 찢어질 것같이 아파할 수 없어 난 어떻게 내가 어떻게 너를 이후에 우리 바다처럼 깊은 사랑이 다 마를 때까지 기다리는 게 이별일 텐데']

# %%
query = "겨울 봄바람"
tokenized_query = bigram(query)
tokenized_query
# Out:
# ['겨울', '봄바', '바람']

# %%
doc_scores = bm25.get_scores(tokenized_query)
doc_scores
# Out:
# array([0.        , 0.08433399, 1.38464544])

# %%
bm25.get_top_n(tokenized_query, corpus, n=1)
# Out:
# ['처음이란 건 돌아보면 네가 흘렸던 작은 말들 무심한 듯 담았어 나도 모르게 하늘을 봐도 알 수 없어 네가 말하던 그 계절이 오면 혹시라도 그대가 여기 흰 눈 속에서 보이는 시린 기억이 스쳐요 그댈 본다면 나을까요 걷다 보면 이따금 속삭여 했던 말들 기억하고 있어요 흰 거리에서 보이는 겨울바람이 스쳐요 그댈 본다면 나 울까요 날 붙잡던 손 날 보던 그 두 눈이 언젠가 날 꼭 안아주세요 참을 수 있죠 조금 망설이면 어느새 그댄 내 곁으로 다가와 아무 생각 않을래요 끝이라고 생각했죠 처음 모습대로 날 기억하나요 겨울인데도 봄바람이 부네요 하얀 눈이 걷히면 이곳에 그대가 있겠죠 따스한 햇살이 부는 날 너에게로 다시 돌아가 너와 함께한 기억처럼만']
